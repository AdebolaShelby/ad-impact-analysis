# %% [markdown]
# # Data Import & Cleaning

# %%
#import dependencies
import os
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import seaborn as sns
from pathlib import Path

# %% [markdown]
# # Campaign Performance Import & Cleaning

# %%
# Combine the current working directory with the relative path
file = os.path.join("Resources", "Campaign performance.csv")

# Read the csv file with historical data from 2021 - 2024
df = pd.read_csv(file)

# Display the data table for preview
df.head(10)
# Out:
#    Year   Month Currency code      Cost  Clicks    Impr.     CTR  Avg. CPC  \
# 0  2021  21-Jan           USD  14704.12  35,298  362,238   9.74%      0.42
# 1  2021  21-Feb           USD  14417.37  31,320  266,177  11.77%      0.46
# 2  2021  21-Mar           USD  17015.18  36,694  359,623  10.20%      0.46
# 3  2021  21-Apr           USD  20799.60  42,823  389,425  11.00%      0.49
# 4  2021  21-May           USD  15546.60  30,229  328,758   9.19%      0.51
# 5  2021  21-Jun           USD  17890.07  42,198  357,839  11.79%      0.42
# 6  2021  21-Jul           USD  21247.44  57,338  442,220  12.97%      0.37
# 7  2021  21-Aug           USD  24122.15  60,731  490,402  12.38%      0.40
# 8  2021  21-Sep           USD  25373.93  61,548  564,992  10.89%      0.41
# 9  2021  21-Oct           USD  27043.32  62,443  436,358  14.31%      0.43
#
#      Revenue Conversions Conv. rate
# 0  161608.75    1,455.45      4.12%
# 1  136573.01    1,301.83      4.16%
# 2  175560.12    1,634.24      4.45%
# 3  204475.32    1,827.76      4.27%
# 4  162003.50    1,415.83      4.68%
# 5  199008.02    1,643.40      3.89%
# 6  307275.57    2,132.63      3.72%
# 7  316354.11    2,182.71      3.59%
# 8  361900.72    2,420.25      3.93%
# 9  328663.68    2,361.72      3.78%

# %%
#count the number of rows in the dataframe
df.count()
# Out:
# Year             49
# Month            49
# Currency code    49
# Cost             49
# Clicks           49
# Impr.            49
# CTR              49
# Avg. CPC         49
# Revenue          49
# Conversions      49
# Conv. rate       49
# dtype: int64

# %%
# drop columns that are not needed
df = df.drop(columns=['Currency code', 'CTR', 'Avg. CPC', 'Conversions', 'Conv. rate', 'Revenue'])
df.head(10)
# Out:
#    Year   Month      Cost  Clicks    Impr.
# 0  2021  21-Jan  14704.12  35,298  362,238
# 1  2021  21-Feb  14417.37  31,320  266,177
# 2  2021  21-Mar  17015.18  36,694  359,623
# 3  2021  21-Apr  20799.60  42,823  389,425
# 4  2021  21-May  15546.60  30,229  328,758
# 5  2021  21-Jun  17890.07  42,198  357,839
# 6  2021  21-Jul  21247.44  57,338  442,220
# 7  2021  21-Aug  24122.15  60,731  490,402
# 8  2021  21-Sep  25373.93  61,548  564,992
# 9  2021  21-Oct  27043.32  62,443  436,358

# %%
# Rename rows in the Month column to name of the month
df['Month'] = df['Month'].replace({
    '21-Jan': 'January', 
    '21-Feb': 'February', 
    '21-Mar': 'March', 
    '21-Apr': 'April', 
    '21-May': 'May', 
    '21-Jun': 'June', 
    '21-Jul': 'July', 
    '21-Aug': 'August', 
    '21-Sep': 'September', 
    '21-Oct': 'October', 
    '21-Nov': 'November', 
    '21-Dec': 'December',
    '22-Jan': 'January', 
    '22-Feb': 'February', 
    '22-Mar': 'March', 
    '22-Apr': 'April', 
    '22-May': 'May', 
    '22-Jun': 'June', 
    '22-Jul': 'July', 
    '22-Aug': 'August', 
    '22-Sep': 'September', 
    '22-Oct': 'October', 
    '22-Nov': 'November', 
    '22-Dec': 'December',
    '23-Jan': 'January', 
    '23-Feb': 'February', 
    '23-Mar': 'March', 
    '23-Apr': 'April', 
    '23-May': 'May', 
    '23-Jun': 'June', 
    '23-Jul': 'July', 
    '23-Aug': 'August', 
    '23-Sep': 'September', 
    '23-Oct': 'October', 
    '23-Nov': 'November', 
    '23-Dec': 'December',
    '24-Jan': 'January',
    '24-Feb': 'February',   
    '24-Mar': 'March',
    '24-Apr': 'April',
    '24-May': 'May',
    '24-Jun': 'June',
    '24-Jul': 'July',
    '24-Aug': 'August',
    '24-Sep': 'September',
    '24-Oct': 'October',
    '24-Nov': 'November',
    '24-Dec': 'December',
    '25-Jan': 'January'
    
})
df.head(50)
# Out:
#     Year      Month      Cost   Clicks      Impr.
# 0   2021    January  14704.12   35,298    362,238
# 1   2021   February  14417.37   31,320    266,177
# 2   2021      March  17015.18   36,694    359,623
# 3   2021      April  20799.60   42,823    389,425
# 4   2021        May  15546.60   30,229    328,758
# 5   2021       June  17890.07   42,198    357,839
# 6   2021       July  21247.44   57,338    442,220
# 7   2021     August  24122.15   60,731    490,402
# 8   2021  September  25373.93   61,548    564,992
# 9   2021    October  27043.32   62,443    436,358
# 10  2021   November  31352.82   66,781    471,638
# 11  2021   December  36009.70   69,060    470,121
# 12  2022    January  35615.68   73,254    514,042
# 13  2022   February  34002.76   66,257    485,430
# 14  2022      March  46514.65   87,248    598,060
# 15  2022      April  41303.78   79,052    559,841
# 16  2022        May  37572.79   76,280    642,775
# 17  2022       June  38169.74   75,619    573,131
# 18  2022       July  40833.50   85,330    640,709
# 19  2022     August  39719.02   95,272  1,456,093
# 20  2022  September  40413.15  103,542  2,588,390
# 21  2022    October  44322.15  102,938  1,862,954
# 22  2022   November  68230.79  120,598  3,358,769
# 23  2022   December  59228.11  112,465  2,993,246
# 24  2023    January  71178.08  137,258  4,638,419
# 25  2023   February  56597.93  122,597  3,589,805
# 26  2023      March  72658.04  137,723  5,325,996
# 27  2023      April  75598.62  132,785  5,275,014
# 28  2023        May  65085.29  114,894  4,345,887
# 29  2023       June  54678.87  102,061  2,966,699
# 30  2023       July  53137.71  109,405  2,777,110
# 31  2023     August  78476.27  131,650  3,506,780
# 32  2023  September  74761.25  120,590  3,237,274
# 33  2023    October  76249.58  148,329  3,366,519
# 34  2023   November  89591.67  163,940  4,403,938
# 35  2023   December  71986.45  149,076  4,413,276
# 36  2024    January  72640.95  161,879  4,223,322
# 37  2024   February  69539.16  164,170  3,741,858
# 38  2024      March  70999.64  153,223  3,211,886
# 39  2024      April  66141.17  135,359  3,584,601
# 40  2024        May  75513.99  134,579  4,317,858
# 41  2024       June  62121.33  123,211  3,969,074
# 42  2024       July  74242.79  133,124  4,519,389
# 43  2024     August  68622.71  131,745  4,644,514
# 44  2024  September  61914.52  133,701  4,078,345
# 45  2024    October  80202.93  155,917  5,168,023
# 46  2024   November  74655.30  150,194  4,045,549
# 47  2024   December  79955.40  152,542  4,681,506
# 48  2025    January  73595.93  154,346  4,354,768

# %%
# convert the month column to datetime
df['Month'] = pd.to_datetime(df['Month'], format='%B').dt.month

#convert the year column to datetime
df['Year'] = pd.to_datetime(df['Year'], format='%Y').dt.year

# %%
# Display the datatypes
df.dtypes
# Out:
# Year        int32
# Month       int32
# Cost      float64
# Clicks     object
# Impr.      object
# dtype: object

# %%
# Reset the index and drop the index column
df.reset_index(drop=True, inplace=True)

# Display the first 10 rows of the dataframe
df.head(10)
# Out:
#    Year  Month      Cost  Clicks    Impr.
# 0  2021      1  14704.12  35,298  362,238
# 1  2021      2  14417.37  31,320  266,177
# 2  2021      3  17015.18  36,694  359,623
# 3  2021      4  20799.60  42,823  389,425
# 4  2021      5  15546.60  30,229  328,758
# 5  2021      6  17890.07  42,198  357,839
# 6  2021      7  21247.44  57,338  442,220
# 7  2021      8  24122.15  60,731  490,402
# 8  2021      9  25373.93  61,548  564,992
# 9  2021     10  27043.32  62,443  436,358

# %%
# display data types
df.dtypes
# Out:
# Year        int32
# Month       int32
# Cost      float64
# Clicks     object
# Impr.      object
# dtype: object

# %%
# create a dataframe for converting date columns to datetime


# convert the date columns to datetime

# %%
# Check for any NaT values that indicate conversion issues
df.isnull().sum()
# Out:
# Year      0
# Month     0
# Cost      0
# Clicks    0
# Impr.     0
# dtype: int64

# %%
# count the number of rows in the dataframe
df.count()
# Out:
# Year      49
# Month     49
# Cost      49
# Clicks    49
# Impr.     49
# dtype: int64

# %%
# display data types

# %%
# save the grouped data to a csv file
df.to_csv('Resources/cleaned_google_ads_data.csv', index=False)

# %% [markdown]
# # GA 4 Import & Cleaning

# %%
# Combine the current working directory with the relative path
ga4_file = os.path.join("Resources", "Traffic_acquisition.csv")

# Read the csv file with historical data from 2022 - 2024
ga4_df = pd.read_csv(ga4_file)

# Display the data table for preview
ga4_df.head(10)
# Out:
#         Date     Channel  Sessions  Engaged sessions  Engagement rate  \
# 0  3/10/2024      Direct     20379              9488         0.465577
# 1  8/26/2022  Unassigned     16968                 0         0.000000
# 2  8/24/2022  Unassigned     16658                 0         0.000000
# 3   3/9/2024      Direct     16572              6849         0.413287
# 4  8/25/2022  Unassigned     16484                 0         0.000000
# 5  8/22/2022  Unassigned     16458                 0         0.000000
# 6  8/23/2022  Unassigned     16003                 0         0.000000
# 7  7/12/2024      Direct     15063             10090         0.669853
# 8  7/16/2024      Direct     14044              9072         0.645970
# 9   2/3/2023      Direct     13643              3430         0.251411
#
#    Average engagement time per session  Events per session  Event count  \
# 0                            69.170175           10.589970       215813
# 1                           108.200849            9.119873       154746
# 2                           117.884380            9.453536       157477
# 3                            66.205226           10.127021       167825
# 4                           114.452985            9.447525       155733
# 5                           114.278466            9.409588       154863
# 6                           120.657064            9.812973       157037
# 7                            44.303924            9.690301       145965
# 8                            32.094062            8.464540       118876
# 9                            32.778055            4.958587        67650
#
#    Key events  Session key event rate  Total revenue
# 0         220                0.010648       34345.03
# 1         269                0.015677       41914.06
# 2         271                0.016148       41627.16
# 3         163                0.009776       25693.29
# 4         260                0.015712       43352.59
# 5         238                0.014279       38161.80
# 6         239                0.014747       37627.56
# 7         120                0.007900       20177.51
# 8          79                0.005554       13142.68
# 9          66                0.004838       10440.39

# %%
# Ensure the date column is in datetime format
ga4_df['Date'] = pd.to_datetime(ga4_df['Date'])

# Create new columns for month, year, and day
ga4_df['Year'] = ga4_df['Date'].dt.year
ga4_df['Month'] = ga4_df['Date'].dt.month
ga4_df['Day'] = ga4_df['Date'].dt.day

# Display the first 10 rows of the dataframe to verify
ga4_df.head(10)
# Out:
#         Date     Channel  Sessions  Engaged sessions  Engagement rate  \
# 0 2024-03-10      Direct     20379              9488         0.465577
# 1 2022-08-26  Unassigned     16968                 0         0.000000
# 2 2022-08-24  Unassigned     16658                 0         0.000000
# 3 2024-03-09      Direct     16572              6849         0.413287
# 4 2022-08-25  Unassigned     16484                 0         0.000000
# 5 2022-08-22  Unassigned     16458                 0         0.000000
# 6 2022-08-23  Unassigned     16003                 0         0.000000
# 7 2024-07-12      Direct     15063             10090         0.669853
# 8 2024-07-16      Direct     14044              9072         0.645970
# 9 2023-02-03      Direct     13643              3430         0.251411
#
#    Average engagement time per session  Events per session  Event count  \
# 0                            69.170175           10.589970       215813
# 1                           108.200849            9.119873       154746
# 2                           117.884380            9.453536       157477
# 3                            66.205226           10.127021       167825
# 4                           114.452985            9.447525       155733
# 5                           114.278466            9.409588       154863
# 6                           120.657064            9.812973       157037
# 7                            44.303924            9.690301       145965
# 8                            32.094062            8.464540       118876
# 9                            32.778055            4.958587        67650
#
#    Key events  Session key event rate  Total revenue  Year  Month  Day
# 0         220                0.010648       34345.03  2024      3   10
# 1         269                0.015677       41914.06  2022      8   26
# 2         271                0.016148       41627.16  2022      8   24
# 3         163                0.009776       25693.29  2024      3    9
# 4         260                0.015712       43352.59  2022      8   25
# 5         238                0.014279       38161.80  2022      8   22
# 6         239                0.014747       37627.56  2022      8   23
# 7         120                0.007900       20177.51  2024      7   12
# 8          79                0.005554       13142.68  2024      7   16
# 9          66                0.004838       10440.39  2023      2    3

# %%
# Agggregate the total sessions, engaged sessions, engagement rate, average engagement time persession, event per session, 
# event count, key events, and total revenue, group by channel , year and month


# Group by 'channel', 'Year', and 'Month' and aggregate the specified columns
aggregated_ga4_df = ga4_df.groupby(['Channel', 'Year', 'Month']).agg({
    'Sessions': 'sum',
    'Engaged sessions': 'sum',
    'Engagement rate': 'mean',
    'Average engagement time per session': 'mean',
    'Events per session': 'mean',
    'Event count': 'sum',
    'Key events': 'sum',
    'Total revenue': 'sum'
}).reset_index()

# Sort the aggregated dataframe by 'Year' and 'Month' in ascending order
aggregated_ga4_df = aggregated_ga4_df.sort_values(by=['Year', 'Month'], ascending=[True, True])

# Display the aggregated dataframe to verify results
print("Aggregated DataFrame by Year and Month:")


print(aggregated_ga4_df[aggregated_ga4_df['Month'] == 5][aggregated_ga4_df['Year'] == 2022])

# Display the first 10 rows of the aggregated dataframe
aggregated_ga4_df.head(10)
# Out:
# Aggregated DataFrame by Year and Month:
#               Channel  Year  Month  Sessions  Engaged sessions  \
# 35             Direct  2022      5    114686             57415
# 68            Display  2022      5         1                 1
# 100             Email  2022      5      9314              5330
# 133    Organic Search  2022      5    124467             87154
# 166  Organic Shopping  2022      5       322               198
# 199    Organic Social  2022      5     19166             11862
# 232     Organic Video  2022      5       258               158
# 265        Paid Other  2022      5         9                 4
# 295       Paid Search  2022      5    105480             78351
# 328     Paid Shopping  2022      5       947               573
# 361       Paid Social  2022      5        24                 4
# 394          Referral  2022      5      5671              3853
# 427               SMS  2022      5         8                 2
# 453        Unassigned  2022      5      3628               667
#
#      Engagement rate  Average engagement time per session  Events per session  \
# 35          0.522395                            86.894168            9.163713
# 68          1.000000                             5.000000            4.000000
# 100         0.516594                           117.655536           11.232905
# 133         0.702568                           124.623657           11.306114
# 166         0.629803                            85.337400           12.219028
# 199         0.620123                            72.765380            8.069038
# 232         0.640886                           101.735696           11.149796
# 265         0.357143                            17.214286            4.714286
# 295         0.745207                           155.326486           12.341466
# 328         0.607895                            95.274728            7.860947
# 361         0.205882                             2.441176            3.299020
# 394         0.681069                           130.115915           12.503112
# 427         0.285714                             9.285714            3.857143
# 453         0.101962                           177.908172           11.186715
#
#      Event count  Key events  Total revenue
# 35       1019490        1486      221493.95
# 68             4           0           0.00
# 100        86048          99       13936.86
# 133      1403767        1591      230027.72
# 166         3944          57        8731.31
# 199       154276          57        7735.51
# 232         2700           1          76.79
# 265           50           0           0.00
# 295      1297667        1900      295522.55
# 328         7556           9        1566.15
# 361           79           0           0.00
# 394        70715         157       21269.30
# 427           29           0           0.00
# 453        37100          83       14484.04
# C:\Users\a3588\AppData\Local\Temp\ipykernel_16220\1319988069.py:24: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(aggregated_ga4_df[aggregated_ga4_df['Month'] == 5][aggregated_ga4_df['Year'] == 2022])
#               Channel  Year  Month  Sessions  Engaged sessions  \
# 35             Direct  2022      5    114686             57415
# 68            Display  2022      5         1                 1
# 100             Email  2022      5      9314              5330
# 133    Organic Search  2022      5    124467             87154
# 166  Organic Shopping  2022      5       322               198
# 199    Organic Social  2022      5     19166             11862
# 232     Organic Video  2022      5       258               158
# 265        Paid Other  2022      5         9                 4
# 295       Paid Search  2022      5    105480             78351
# 328     Paid Shopping  2022      5       947               573
#
#      Engagement rate  Average engagement time per session  Events per session  \
# 35          0.522395                            86.894168            9.163713
# 68          1.000000                             5.000000            4.000000
# 100         0.516594                           117.655536           11.232905
# 133         0.702568                           124.623657           11.306114
# 166         0.629803                            85.337400           12.219028
# 199         0.620123                            72.765380            8.069038
# 232         0.640886                           101.735696           11.149796
# 265         0.357143                            17.214286            4.714286
# 295         0.745207                           155.326486           12.341466
# 328         0.607895                            95.274728            7.860947
#
#      Event count  Key events  Total revenue
# 35       1019490        1486      221493.95
# 68             4           0           0.00
# 100        86048          99       13936.86
# 133      1403767        1591      230027.72
# 166         3944          57        8731.31
# 199       154276          57        7735.51
# 232         2700           1          76.79
# 265           50           0           0.00
# 295      1297667        1900      295522.55
# 328         7556           9        1566.15

# %%
# check for any missing values
aggregated_ga4_df.isnull().sum()
# Out:
# Channel                                0
# Year                                   0
# Month                                  0
# Sessions                               0
# Engaged sessions                       0
# Engagement rate                        0
# Average engagement time per session    0
# Events per session                     0
# Event count                            0
# Key events                             0
# Total revenue                          0
# dtype: int64

# %%
# check for null values
aggregated_ga4_df.isnull().sum()
# Out:
# Channel                                0
# Year                                   0
# Month                                  0
# Sessions                               0
# Engaged sessions                       0
# Engagement rate                        0
# Average engagement time per session    0
# Events per session                     0
# Event count                            0
# Key events                             0
# Total revenue                          0
# dtype: int64

# %%
# Drop the columns not needed

# drop the rows not display, referral, sms, paid social, unassigned, affiliates, and email row under the channel column
aggregated_ga4_df = aggregated_ga4_df[aggregated_ga4_df['Channel'] != 'Display']
aggregated_ga4_df = aggregated_ga4_df[aggregated_ga4_df['Channel'] != 'Email']
aggregated_ga4_df = aggregated_ga4_df[aggregated_ga4_df['Channel'] != 'Referral']
aggregated_ga4_df = aggregated_ga4_df[aggregated_ga4_df['Channel'] != 'SMS']
aggregated_ga4_df = aggregated_ga4_df[aggregated_ga4_df['Channel'] != 'Paid Social']
aggregated_ga4_df = aggregated_ga4_df[aggregated_ga4_df['Channel'] != 'Unassigned']
aggregated_ga4_df = aggregated_ga4_df[aggregated_ga4_df['Channel'] != 'Affiliates']

# Drop the Average enagagement time per session, Event per session, and Key events column
aggregated_ga4_df = aggregated_ga4_df.drop(columns=['Average engagement time per session'])
aggregated_ga4_df = aggregated_ga4_df.drop(columns=['Events per session'])
aggregated_ga4_df = aggregated_ga4_df.drop(columns=['Key events'])


# Display the first 10 rows of the dataframe
aggregated_ga4_df.head(10)
# Out:
#               Channel  Year  Month  Sessions  Engaged sessions  \
# 35             Direct  2022      5    114686             57415
# 133    Organic Search  2022      5    124467             87154
# 166  Organic Shopping  2022      5       322               198
# 199    Organic Social  2022      5     19166             11862
# 232     Organic Video  2022      5       258               158
# 265        Paid Other  2022      5         9                 4
# 295       Paid Search  2022      5    105480             78351
# 328     Paid Shopping  2022      5       947               573
# 36             Direct  2022      6    114188             57617
# 134    Organic Search  2022      6    148130            102576
#
#      Engagement rate  Event count  Total revenue
# 35          0.522395      1019490      221493.95
# 133         0.702568      1403767      230027.72
# 166         0.629803         3944        8731.31
# 199         0.620123       154276        7735.51
# 232         0.640886         2700          76.79
# 265         0.357143           50           0.00
# 295         0.745207      1297667      295522.55
# 328         0.607895         7556        1566.15
# 36          0.514760      1002905      242453.10
# 134         0.692626      1682680      300341.69

# %%
# change the month column to the name of the month
aggregated_ga4_df['Month'] = aggregated_ga4_df['Month'].replace({
    1: 'January', 
    2: 'February', 
    3: 'March', 
    4: 'April', 
    5: 'May', 
    6: 'June', 
    7: 'July', 
    8: 'August', 
    9: 'September', 
    10: 'October', 
    11: 'November', 
    12: 'December'
})

# Display the first 10 rows of the dataframe
aggregated_ga4_df.head(10)
# Out:
#               Channel  Year Month  Sessions  Engaged sessions  \
# 35             Direct  2022   May    114686             57415
# 133    Organic Search  2022   May    124467             87154
# 166  Organic Shopping  2022   May       322               198
# 199    Organic Social  2022   May     19166             11862
# 232     Organic Video  2022   May       258               158
# 265        Paid Other  2022   May         9                 4
# 295       Paid Search  2022   May    105480             78351
# 328     Paid Shopping  2022   May       947               573
# 36             Direct  2022  June    114188             57617
# 134    Organic Search  2022  June    148130            102576
#
#      Engagement rate  Event count  Total revenue
# 35          0.522395      1019490      221493.95
# 133         0.702568      1403767      230027.72
# 166         0.629803         3944        8731.31
# 199         0.620123       154276        7735.51
# 232         0.640886         2700          76.79
# 265         0.357143           50           0.00
# 295         0.745207      1297667      295522.55
# 328         0.607895         7556        1566.15
# 36          0.514760      1002905      242453.10
# 134         0.692626      1682680      300341.69

# %%
# check the data types
aggregated_ga4_df.dtypes
# Out:
# Channel              object
# Year                  int32
# Month                object
# Sessions              int64
# Engaged sessions      int64
# Engagement rate     float64
# Event count           int64
# Total revenue       float64
# dtype: object

# %%
# save cleaned ga4 data to a csv file
aggregated_ga4_df.to_csv('Resources/cleaned_google_analytics_data.csv', index=False)

# %% [markdown]
# # Exploratory Analysis

# %%
# plot ga4 sessions for organic search, direct and paid search for the year 2023 and 2024
import matplotlib.pyplot as plt
import seaborn as sns
# Filter the dataframe for the year 2023
ga4_2023_df = aggregated_ga4_df[aggregated_ga4_df['Year'] == 2023]

# Filter the dataframe for the channels 'Organic Search', 'Direct', and 'Paid Search'
ga4_2023_df = ga4_2023_df[ga4_2023_df['Channel'].isin(['Organic Search', 'Direct', 'Paid Search'])]

# Display the first 10 rows of the dataframe
ga4_2023_df.head(10)

# Plot the sessions for the channels 'Organic Search', 'Direct', and 'Paid Search' for the year 2023
plt.figure(figsize=(12, 8)) 
sns.lineplot(data=ga4_2023_df, x='Month', y='Sessions', hue='Channel', marker='o')
plt.title('Sessions by Channel for the Year 2023')
plt.xlabel('Month')
plt.ylabel('Sessions')
plt.grid()
plt.legend(title='Channel')
plt.tight_layout()
plt.show()

# %%
# plot sessions for organic search, direct and paid search for the year 2023 and 2024
import matplotlib.pyplot as plt
import seaborn as sns
# Filter the dataframe for the year 2024
ga4_2024_df = aggregated_ga4_df[aggregated_ga4_df['Year'] == 2024]

# Filter the dataframe for the channels 'Organic Search', 'Direct', and 'Paid Search'
ga4_2024_df = ga4_2024_df[ga4_2024_df['Channel'].isin(['Organic Search', 'Direct', 'Paid Search'])]

# Display the first 10 rows of the dataframe
ga4_2024_df.head(10)

# Plot the sessions for the channels 'Organic Search', 'Direct', and 'Paid Search' for the year 2024
plt.figure(figsize=(12, 8))
sns.lineplot(data=ga4_2024_df, x='Month', y='Sessions', hue='Channel', marker='o')
plt.title('Sessions by Channel for the Year 2024')
plt.xlabel('Month')
plt.ylabel('Sessions')
plt.grid()
plt.legend(title='Channel')
plt.tight_layout()
plt.show()

# %%
# Create a mapping from month names to numeric values
month_mapping = {
    'January': 1, 'February': 2, 'March': 3, 'April': 4, 'May': 5, 'June': 6,
    'July': 7, 'August': 8, 'September': 9, 'October': 10, 'November': 11, 'December': 12
}

# Replace the month names with their corresponding numeric values
aggregated_ga4_df['Month'] = aggregated_ga4_df['Month'].map(month_mapping)

# Create a new column that combines the year and month into a datetime object
aggregated_ga4_df['YearMonth'] = pd.to_datetime(aggregated_ga4_df[['Year', 'Month']].assign(Day=1))

# Filter the data for the years 2023 and 2024
filtered_df = aggregated_ga4_df[(aggregated_ga4_df['Year'] >= 2023) & (aggregated_ga4_df['Year'] <= 2024)]

# Further filter the data to include only Paid Search, Direct, and Organic Search channels
filtered_df = filtered_df[filtered_df['Channel'].isin(['Paid Search', 'Direct', 'Organic Search'])]

# Generate a range of dates for the x-axis ticks
date_range = pd.date_range(start='2023-01-01', end='2024-12-31', freq='MS')

# Plot the data
plt.figure(figsize=(18, 8))
sns.lineplot(data=filtered_df, x='YearMonth', y='Sessions', hue='Channel', ci=None, marker='o')
plt.title('Sessions by Channel for the Years 2023 and 2024')
plt.xlabel('Date')
plt.ylabel('Sessions')

# Customize the x-axis tick labels to show only month and year
date_form = DateFormatter("%b %Y")
plt.gca().xaxis.set_major_formatter(date_form)

plt.xticks(date_range, rotation=45)
plt.grid()
plt.legend(title='Channel')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\a3588\AppData\Local\Temp\ipykernel_16220\2414581104.py:24: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=filtered_df, x='YearMonth', y='Sessions', hue='Channel', ci=None, marker='o')

# %%
# Plot total revenue by channels for the years 2023 and 2024

# Print unique values in the Month column before conversion
print("Unique values in the Month column before conversion:")
print(ga4_df['Month'].unique())

# Convert the Month column to string values
ga4_df['Month'] = ga4_df['Month'].astype(str)

# Combine the Year and Month columns into a single string column
ga4_df['YearMonthStr'] = ga4_df['Year'].astype(str) + '-' + ga4_df['Month']

# Print the combined YearMonthStr column
print("Combined YearMonthStr column:")
print(ga4_df['YearMonthStr'].head())

# Convert the combined YearMonthStr column to a datetime object
ga4_df['YearMonth'] = pd.to_datetime(ga4_df['YearMonthStr'], format='%Y-%m', errors='coerce')

# Print unique values in the YearMonth column after conversion
print("Unique values in the YearMonth column after conversion:")
print(ga4_df['YearMonth'].unique())

# Verify the data after creating the YearMonth column
print("Data after creating YearMonth column:")
print(ga4_df[['YearMonth', 'Channel', 'Total revenue']].head())

# Filter the data for the years 2023 and 2024
filtered_df = ga4_df[(ga4_df['YearMonth'] >= '2023-01-01') & (ga4_df['YearMonth'] <= '2024-12-31')]

# Verify the data after filtering by year
print("Data after filtering by year:")
print(filtered_df[['YearMonth', 'Channel', 'Total revenue']].head())

# Further filter the data to include only Paid Search, Direct, and Organic Search channels
filtered_df = filtered_df[filtered_df['Channel'].isin(['Paid Search', 'Direct', 'Organic Search'])]

# Verify the data after filtering by channel
print("Data after filtering by channel:")
print(filtered_df[['YearMonth', 'Channel', 'Total revenue']].head())

# Generate a range of dates for the x-axis ticks
date_range = pd.date_range(start='2023-01-01', end='2024-12-31', freq='MS')

# Plot the data for total revenue
plt.figure(figsize=(18, 8))
sns.lineplot(data=filtered_df, x='YearMonth', y='Total revenue', hue='Channel', errorbar=None, marker='o')
plt.title('Total Revenue by Channel for the Years 2023 and 2024')
plt.xlabel('Date')
plt.ylabel('Total Revenue')

# Customize the x-axis tick labels to show only month and year
date_form = DateFormatter("%b %Y")
plt.gca().xaxis.set_major_formatter(date_form)

plt.xticks(date_range, rotation=45)
plt.grid()
plt.legend(title='Channel')
plt.tight_layout()
plt.show()
# Out:
# Unique values in the Month column before conversion:
# [ 3  8  7  2 11 12  6  4  5  1 10  9]
# Combined YearMonthStr column:
# 0    2024-3
# 1    2022-8
# 2    2022-8
# 3    2024-3
# 4    2022-8
# Name: YearMonthStr, dtype: object
# Unique values in the YearMonth column after conversion:
# <DatetimeArray>
# ['2024-03-01 00:00:00', '2022-08-01 00:00:00', '2024-07-01 00:00:00',
#  '2023-02-01 00:00:00', '2022-11-01 00:00:00', '2024-08-01 00:00:00',
#  '2022-12-01 00:00:00', '2023-03-01 00:00:00', '2024-06-01 00:00:00',
#  '2023-04-01 00:00:00', '2022-05-01 00:00:00', '2023-01-01 00:00:00',
#  '2022-10-01 00:00:00', '2024-04-01 00:00:00', '2024-02-01 00:00:00',
#  '2022-09-01 00:00:00', '2024-11-01 00:00:00', '2025-01-01 00:00:00',
#  '2023-06-01 00:00:00', '2024-05-01 00:00:00', '2024-12-01 00:00:00',
#  '2024-01-01 00:00:00', '2023-10-01 00:00:00', '2023-12-01 00:00:00',
#  '2024-10-01 00:00:00', '2023-09-01 00:00:00', '2023-08-01 00:00:00',
#  '2023-11-01 00:00:00', '2023-05-01 00:00:00', '2022-06-01 00:00:00',
#  '2023-07-01 00:00:00', '2024-09-01 00:00:00', '2022-07-01 00:00:00']
# Length: 33, dtype: datetime64[ns]
# Data after creating YearMonth column:
#    YearMonth     Channel  Total revenue
# 0 2024-03-01      Direct       34345.03
# 1 2022-08-01  Unassigned       41914.06
# 2 2022-08-01  Unassigned       41627.16
# 3 2024-03-01      Direct       25693.29
# 4 2022-08-01  Unassigned       43352.59
# Data after filtering by year:
#    YearMonth Channel  Total revenue
# 0 2024-03-01  Direct       34345.03
# 3 2024-03-01  Direct       25693.29
# 7 2024-07-01  Direct       20177.51
# 8 2024-07-01  Direct       13142.68
# 9 2023-02-01  Direct       10440.39
# Data after filtering by channel:
#    YearMonth Channel  Total revenue
# 0 2024-03-01  Direct       34345.03
# 3 2024-03-01  Direct       25693.29
# 7 2024-07-01  Direct       20177.51
# 8 2024-07-01  Direct       13142.68
# 9 2023-02-01  Direct       10440.39

# %% [markdown]
# # Merge GA 4 Data and Campaign Performance Data

# %%
# merge the google ads and google analytics data
# Merge the Google Ads and Google Analytics data on 'Year' and 'Month'
merged_df = pd.merge(df, aggregated_ga4_df, on=['Year', 'Month'], how='inner')

# Display the first 10 rows of the merged dataframe
merged_df.head(10)
# Out:
#    Year  Month      Cost  Clicks    Impr.           Channel  Sessions  \
# 0  2022      5  37572.79  76,280  642,775            Direct    114686
# 1  2022      5  37572.79  76,280  642,775    Organic Search    124467
# 2  2022      5  37572.79  76,280  642,775  Organic Shopping       322
# 3  2022      5  37572.79  76,280  642,775    Organic Social     19166
# 4  2022      5  37572.79  76,280  642,775     Organic Video       258
# 5  2022      5  37572.79  76,280  642,775        Paid Other         9
# 6  2022      5  37572.79  76,280  642,775       Paid Search    105480
# 7  2022      5  37572.79  76,280  642,775     Paid Shopping       947
# 8  2022      6  38169.74  75,619  573,131            Direct    114188
# 9  2022      6  38169.74  75,619  573,131    Organic Search    148130
#
#    Engaged sessions  Engagement rate  Event count  Total revenue  YearMonth
# 0             57415         0.522395      1019490      221493.95 2022-05-01
# 1             87154         0.702568      1403767      230027.72 2022-05-01
# 2               198         0.629803         3944        8731.31 2022-05-01
# 3             11862         0.620123       154276        7735.51 2022-05-01
# 4               158         0.640886         2700          76.79 2022-05-01
# 5                 4         0.357143           50           0.00 2022-05-01
# 6             78351         0.745207      1297667      295522.55 2022-05-01
# 7               573         0.607895         7556        1566.15 2022-05-01
# 8             57617         0.514760      1002905      242453.10 2022-06-01
# 9            102576         0.692626      1682680      300341.69 2022-06-01

# %%
# exclude the rows with the channel column as referral, sms, paid social, unassigned, affiliates, and email
merged_df = merged_df[merged_df['Channel'] != 'Referral']
merged_df = merged_df[merged_df['Channel'] != 'SMS']
merged_df = merged_df[merged_df['Channel'] != 'Paid Social']
merged_df = merged_df[merged_df['Channel'] != 'Unassigned']
merged_df = merged_df[merged_df['Channel'] != 'Affiliates']
merged_df = merged_df[merged_df['Channel'] != 'Email']

# Display the first 10 rows of the merged dataframe
merged_df.head(10)
# Out:
#    Year  Month      Cost  Clicks    Impr.           Channel  Sessions  \
# 0  2022      5  37572.79  76,280  642,775            Direct    114686
# 1  2022      5  37572.79  76,280  642,775    Organic Search    124467
# 2  2022      5  37572.79  76,280  642,775  Organic Shopping       322
# 3  2022      5  37572.79  76,280  642,775    Organic Social     19166
# 4  2022      5  37572.79  76,280  642,775     Organic Video       258
# 5  2022      5  37572.79  76,280  642,775        Paid Other         9
# 6  2022      5  37572.79  76,280  642,775       Paid Search    105480
# 7  2022      5  37572.79  76,280  642,775     Paid Shopping       947
# 8  2022      6  38169.74  75,619  573,131            Direct    114188
# 9  2022      6  38169.74  75,619  573,131    Organic Search    148130
#
#    Engaged sessions  Engagement rate  Event count  Total revenue  YearMonth
# 0             57415         0.522395      1019490      221493.95 2022-05-01
# 1             87154         0.702568      1403767      230027.72 2022-05-01
# 2               198         0.629803         3944        8731.31 2022-05-01
# 3             11862         0.620123       154276        7735.51 2022-05-01
# 4               158         0.640886         2700          76.79 2022-05-01
# 5                 4         0.357143           50           0.00 2022-05-01
# 6             78351         0.745207      1297667      295522.55 2022-05-01
# 7               573         0.607895         7556        1566.15 2022-05-01
# 8             57617         0.514760      1002905      242453.10 2022-06-01
# 9            102576         0.692626      1682680      300341.69 2022-06-01

# %%
# print the data types
merged_df.dtypes
# Out:
# Year                         int32
# Month                        int32
# Cost                       float64
# Clicks                      object
# Impr.                       object
# Channel                     object
# Sessions                     int64
# Engaged sessions             int64
# Engagement rate            float64
# Event count                  int64
# Total revenue              float64
# YearMonth           datetime64[ns]
# dtype: object

# %%
# plot ppc cost vs sessions for the year 2023 and 2024
# Filter the data for the years 2023 and 2024
merged_2023_2024_df = merged_df[(merged_df['Year'] >= 2023) & (merged_df['Year'] <= 2024)]

# Generate a range of dates for the x-axis ticks
date_range = pd.date_range(start='2023-01-01', end='2024-12-31', freq='MS')

# Plot the data for Cost vs. Sessions
plt.figure(figsize=(18, 8))
sns.scatterplot(data=merged_2023_2024_df, x='Cost', y='Sessions', hue='Channel', s=100)
plt.title('PPC Cost vs. Sessions for the Years 2023 and 2024')
plt.xlabel('Cost')
plt.ylabel('Sessions')
plt.grid()
plt.legend(title='Channel')
plt.tight_layout()
plt.show()

# %%
# plot ppc cost vs organic search sessions for the year 2023 and 2024
# Filter the data for the years 2023 and 2024
merged_2023_2024_df = merged_df[(merged_df['Year'] >= 2023) & (merged_df['Year'] <= 2024)]

# Filter the data for the channel 'Organic Search'
organic_search_df = merged_2023_2024_df[merged_2023_2024_df['Channel'] == 'Organic Search']

# Generate a range of dates for the x-axis ticks
date_range = pd.date_range(start='2023-01-01', end='2024-12-31', freq='MS')

# Plot the data for Cost vs. Sessions for Organic Search
plt.figure(figsize=(18, 8))
sns.scatterplot(data=organic_search_df, x='Cost', y='Sessions', s=100)
plt.title('PPC Cost vs. Sessions for Organic Search for the Years 2023 and 2024')
plt.xlabel('PPC Cost')
plt.ylabel('Sessions')
plt.grid()
plt.tight_layout()
plt.show()

# %%
# Add a regression line to the scatter plot
plt.figure(figsize=(18, 8))
sns.regplot(data=organic_search_df, x='Cost', y='Sessions', scatter_kws={'s': 100})
plt.title('PPC Cost vs. Sessions for Organic Search with Regression Line for the Years 2023 and 2024')
plt.xlabel('PPC Cost')
plt.ylabel('Sessions')
plt.grid()
plt.tight_layout()
plt.show()


# Calculate the correlation between PPC Cost and Sessions for Organic Search
correlation = organic_search_df['Cost'].corr(organic_search_df['Sessions'])
print(f"Correlation between PPC Cost and Sessions for Organic Search: {correlation}")
# Out:
# Correlation between PPC Cost and Sessions for Organic Search: 0.1432722608630282

# %%
# plot ppc cost vs direct sessions for the year 2023 and 2024
# Filter the data for the years 2023 and 2024
merged_2023_2024_df = merged_df[(merged_df['Year'] >= 2023) & (merged_df['Year'] <= 2024)]

# Filter the data for the channel 'Direct'
direct_df = merged_2023_2024_df[merged_2023_2024_df['Channel'] == 'Direct']

# Generate a range of dates for the x-axis ticks
date_range = pd.date_range(start='2023-01-01', end='2024-12-31', freq='MS')

# Plot the data for Cost vs. Sessions for Direct
plt.figure(figsize=(18, 8))
sns.scatterplot(data=direct_df, x='Cost', y='Sessions', s=100)
plt.title('PPC Cost vs. Sessions for Direct for the Years 2023 and 2024')
plt.xlabel('PPC Cost')
plt.ylabel('Sessions')
plt.grid()
plt.tight_layout()
plt.show()

# %%
# Add a regression line to the scatter plot
plt.figure(figsize=(18, 8))
sns.regplot(data=direct_df, x='Cost', y='Sessions', scatter_kws={'s': 100})
plt.title('PPC Cost vs. Sessions for Direct with Regression Line for the Years 2023 and 2024')
plt.xlabel('PPC Cost')
plt.ylabel('Sessions')
plt.grid()
plt.tight_layout()
plt.show()


# Calculate the correlation between PPC Cost and Sessions for Direct
correlation = direct_df['Cost'].corr(direct_df['Sessions'])
print(f"Correlation between PPC Cost and Sessions for Direct: {correlation}")
# Out:
# Correlation between PPC Cost and Sessions for Direct: 0.003766564328796912

# %%
# Print the first few rows to inspect the data
print("First few rows of the DataFrame:")
print(merged_df.head())

# Identify columns with numeric values stored as strings with commas
columns_to_clean = merged_df.columns[merged_df.apply(lambda x: x.astype(str).str.contains(',').any())]

# Print the columns that need cleaning
print("Columns to clean:")
print(columns_to_clean)

# Remove commas from the identified columns and convert to numeric values
for col in columns_to_clean:
    merged_df[col] = merged_df[col].astype(str).str.replace(',', '').astype(float)

# Verify the data after cleaning
print("Data after cleaning:")
print(merged_df[columns_to_clean].head())

# Select only numeric columns for correlation matrix
numeric_df = merged_df.select_dtypes(include=[float, int])

# Calculate the correlation matrix
correlation_matrix = numeric_df.corr()

# Plot the heatmap of the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# First few rows of the DataFrame:
#    Year  Month      Cost  Clicks    Impr.           Channel  Sessions  \
# 0  2022      5  37572.79  76,280  642,775            Direct    114686
# 1  2022      5  37572.79  76,280  642,775    Organic Search    124467
# 2  2022      5  37572.79  76,280  642,775  Organic Shopping       322
# 3  2022      5  37572.79  76,280  642,775    Organic Social     19166
# 4  2022      5  37572.79  76,280  642,775     Organic Video       258
#
#    Engaged sessions  Engagement rate  Event count  Total revenue  YearMonth
# 0             57415         0.522395      1019490      221493.95 2022-05-01
# 1             87154         0.702568      1403767      230027.72 2022-05-01
# 2               198         0.629803         3944        8731.31 2022-05-01
# 3             11862         0.620123       154276        7735.51 2022-05-01
# 4               158         0.640886         2700          76.79 2022-05-01
# Columns to clean:
# Index(['Clicks', 'Impr.'], dtype='object')
# Data after cleaning:
#     Clicks     Impr.
# 0  76280.0  642775.0
# 1  76280.0  642775.0
# 2  76280.0  642775.0
# 3  76280.0  642775.0
# 4  76280.0  642775.0

# %%
# Create a correlation matrix heat map for the relationship bewtween cost and all the channels like oganic search, paid search, direct, cross-network, organic shopping, organic socail, organic video, paid shopping 

# Print the first few rows to inspect the data
print("First few rows of the DataFrame:")
print(merged_df.head())

# Identify columns with numeric values stored as strings with commas
columns_to_clean = merged_df.columns[merged_df.apply(lambda x: x.astype(str).str.contains(',').any())]

# Print the columns that need cleaning
print("Columns to clean:")
print(columns_to_clean)

# Remove commas from the identified columns and convert to numeric values
for col in columns_to_clean:
    merged_df[col] = merged_df[col].astype(str).str.replace(',', '').astype(float)

# Verify the data after cleaning
print("Data after cleaning:")
print(merged_df[columns_to_clean].head())

# Select only numeric columns for correlation matrix
numeric_df = merged_df.select_dtypes(include=[float, int])

# Calculate the correlation matrix
correlation_matrix = numeric_df.corr()

# Plot the heatmap of the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# First few rows of the DataFrame:
#    Year  Month      Cost   Clicks     Impr.           Channel  Sessions  \
# 0  2022      5  37572.79  76280.0  642775.0            Direct    114686
# 1  2022      5  37572.79  76280.0  642775.0    Organic Search    124467
# 2  2022      5  37572.79  76280.0  642775.0  Organic Shopping       322
# 3  2022      5  37572.79  76280.0  642775.0    Organic Social     19166
# 4  2022      5  37572.79  76280.0  642775.0     Organic Video       258
#
#    Engaged sessions  Engagement rate  Event count  Total revenue  YearMonth
# 0             57415         0.522395      1019490      221493.95 2022-05-01
# 1             87154         0.702568      1403767      230027.72 2022-05-01
# 2               198         0.629803         3944        8731.31 2022-05-01
# 3             11862         0.620123       154276        7735.51 2022-05-01
# 4               158         0.640886         2700          76.79 2022-05-01
# Columns to clean:
# Index([], dtype='object')
# Data after cleaning:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
# Filter data for years 2023 and 2024
merged_2023_2024_df = merged_df[(merged_df['Year'] >= 2023) & (merged_df['Year'] <= 2024)]

# Filter for specific channels
selected_channels = ['Organic Search', 'Paid Search', 'Direct', 'Cross-network', 
                     'Organic Shopping', 'Organic Social', 'Organic Video', 'Paid Shopping']
filtered_df = merged_2023_2024_df[merged_2023_2024_df['Channel'].isin(selected_channels)]

# One-hot encode 'Channel'
encoded_df = pd.get_dummies(filtered_df, columns=['Channel'])

# Compute correlation matrix (including Cost and encoded channels)
correlation_matrix = encoded_df.corr()

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix Heatmap for Cost and Channels')
plt.show()

# %%
# plot ppc cost vs paid search sessions for the year 2023 and 2024
# Filter the data for the years 2023 and 2024

# Filter the data for the channel 'Paid Search'
paid_search_df = merged_2023_2024_df[merged_2023_2024_df['Channel'] == 'Paid Search']

# Generate a range of dates for the x-axis ticks
date_range = pd.date_range(start='2023-01-01', end='2024-12-31', freq='MS')

# Plot the data for Cost vs. Sessions for Paid Search
plt.figure(figsize=(18, 8))
sns.scatterplot(data=paid_search_df, x='Cost', y='Sessions', s=100)
plt.title('PPC Cost vs. Sessions for Paid Search for the Years 2023 and 2024')
plt.xlabel('PPC Cost')
plt.ylabel('Sessions')
plt.grid()
plt.tight_layout()
plt.show()

# %%
# Add a regression line to the scatter plot
plt.figure(figsize=(18, 8))
sns.regplot(data=paid_search_df, x='Cost', y='Sessions', scatter_kws={'s': 100})
plt.title('PPC Cost vs. Sessions for Paid Search with Regression Line for the Years 2023 and 2024')
plt.xlabel('PPC Cost')
plt.ylabel('Sessions')
plt.grid()
plt.tight_layout()
plt.show()

# Calculate the correlation between PPC Cost and Sessions for Paid Search
correlation = paid_search_df['Cost'].corr(paid_search_df['Sessions'])
print(f"Correlation between PPC Cost and Sessions for Paid Search: {correlation}")
# Out:
# Correlation between PPC Cost and Sessions for Paid Search: 0.1196191097050674

# %%
# Filter the data for the years 2023 and 2024
merged_2023_2024_df = merged_df[(merged_df['Year'] >= 2023) & (merged_df['Year'] <= 2024)]

# Filter the data for the specified channels
filtered_df = merged_2023_2024_df[merged_2023_2024_df['Channel'].isin([
    'Organic Search', 'Paid Search', 'Direct', 'Cross-network', 
    'Organic Shopping', 'Organic Social', 'Organic Video', 'Paid Shopping'
])]

# Pivot the data to have channels as columns and 'Cost' as one of the columns
pivot_df = filtered_df.pivot_table(index=['Year', 'Month'], columns='Channel', values='Cost', aggfunc='sum').reset_index()

# Flatten the MultiIndex columns
pivot_df.columns = [f'{col[1]}' if col[1] else col[0] for col in pivot_df.columns]

# Print the pivoted DataFrame to verify
print("Pivoted DataFrame:")
print(pivot_df.head())

# Calculate the correlation matrix
correlation_matrix = pivot_df.corr()

# Plot the heatmap of the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix Heatmap for Cost and Channels')
plt.show()
# Out:
# Pivoted DataFrame:
#       e  o         r         i         r         r         r         r  \
# 0  2023  1  71178.08  71178.08  71178.08  71178.08  71178.08  71178.08
# 1  2023  2  56597.93  56597.93  56597.93  56597.93  56597.93  56597.93
# 2  2023  3  72658.04  72658.04  72658.04  72658.04  72658.04  72658.04
# 3  2023  4  75598.62  75598.62  75598.62  75598.62  75598.62  75598.62
# 4  2023  5  65085.29  65085.29  65085.29  65085.29  65085.29  65085.29
#
#           a         a
# 0  71178.08  71178.08
# 1  56597.93  56597.93
# 2  72658.04  72658.04
# 3  75598.62  75598.62
# 4  65085.29  65085.29
